# %% [markdown]
# # <span style="color:brown;">Clean Column Names</span>

# %%
import polars as pl
from polars import col as c
import re

pl_mkt = pl.read_csv("data/marketing_data.csv")

print(pl_mkt.head())

print(pl_mkt.columns)
# Out:
# shape: (5, 26)
# ┌──────┬──────┬─────────────┬─────────────┬───┬─────────────┬─────────────┬───────────┬────────────┐
# │ week ┆ Year ┆ Market.Shar ┆ Av.Price.pe ┆ … ┆ Reach.cinem ┆ GRP.outdoor ┆ GRP.print ┆ Share.of.s │
# │ ---  ┆ ---  ┆ e           ┆ r.kg        ┆   ┆ a           ┆ ---         ┆ ---       ┆ pend       │
# │ i64  ┆ i64  ┆ ---         ┆ ---         ┆   ┆ ---         ┆ i64         ┆ f64       ┆ ---        │
# │      ┆      ┆ f64         ┆ f64         ┆   ┆ f64         ┆             ┆           ┆ f64        │
# ╞══════╪══════╪═════════════╪═════════════╪═══╪═════════════╪═════════════╪═══════════╪════════════╡
# │ 19   ┆ 2010 ┆ 38.4        ┆ 7.61        ┆ … ┆ null        ┆ null        ┆ null      ┆ null       │
# │ 20   ┆ 2010 ┆ 36.8        ┆ 7.6         ┆ … ┆ null        ┆ null        ┆ null      ┆ null       │
# │ 21   ┆ 2010 ┆ 35.21       ┆ 7.63        ┆ … ┆ null        ┆ null        ┆ null      ┆ null       │
# │ 22   ┆ 2010 ┆ 35.03       ┆ 7.22        ┆ … ┆ null        ┆ null        ┆ null      ┆ null       │
# │ 23   ┆ 2010 ┆ 32.37       ┆ 7.7         ┆ … ┆ null        ┆ null        ┆ null      ┆ null       │
# └──────┴──────┴─────────────┴─────────────┴───┴─────────────┴─────────────┴───────────┴────────────┘
# ['week', 'Year', 'Market.Share', 'Av.Price.per.kg', 'Non-Promo Price.per.kg', 'Promo.Vol.Share', 'Total.Weigh', 'Share.of.Ean.Weigh', 'Avg price.vs.PLB', 'Non.promo.price.vs.PLB', 'Promo.vol.sh.index.vs.PLB', 'Total.cm.shelf', 'Shelf.share', 'Top.of.mind', 'Spontaneous', 'Aided', 'Penetration', 'Competitor', 'GRP.radio', 'Reach.radio', 'GRP.TV', 'Reach.TV', 'Reach.cinema', 'GRP.outdoor', 'GRP.print', 'Share.of.spend']

# %%
pl_mkt = (
    pl_mkt
    .rename(lambda col: re.sub('\\.|\\s+', '_', col.lower()))
)

print(pl_mkt)

print(pl_mkt.columns)
# Out:
# shape: (156, 26)
# ┌──────┬──────┬─────────────┬─────────────┬───┬─────────────┬─────────────┬───────────┬────────────┐
# │ week ┆ year ┆ market_shar ┆ av_price_pe ┆ … ┆ reach_cinem ┆ grp_outdoor ┆ grp_print ┆ share_of_s │
# │ ---  ┆ ---  ┆ e           ┆ r_kg        ┆   ┆ a           ┆ ---         ┆ ---       ┆ pend       │
# │ i64  ┆ i64  ┆ ---         ┆ ---         ┆   ┆ ---         ┆ i64         ┆ f64       ┆ ---        │
# │      ┆      ┆ f64         ┆ f64         ┆   ┆ f64         ┆             ┆           ┆ f64        │
# ╞══════╪══════╪═════════════╪═════════════╪═══╪═════════════╪═════════════╪═══════════╪════════════╡
# │ 19   ┆ 2010 ┆ 38.4        ┆ 7.61        ┆ … ┆ null        ┆ null        ┆ null      ┆ null       │
# │ 20   ┆ 2010 ┆ 36.8        ┆ 7.6         ┆ … ┆ null        ┆ null        ┆ null      ┆ null       │
# │ 21   ┆ 2010 ┆ 35.21       ┆ 7.63        ┆ … ┆ null        ┆ null        ┆ null      ┆ null       │
# │ 22   ┆ 2010 ┆ 35.03       ┆ 7.22        ┆ … ┆ null        ┆ null        ┆ null      ┆ null       │
# │ 23   ┆ 2010 ┆ 32.37       ┆ 7.7         ┆ … ┆ null        ┆ null        ┆ null      ┆ null       │
# │ …    ┆ …    ┆ …           ┆ …           ┆ … ┆ …           ┆ …           ┆ …         ┆ …          │
# │ 14   ┆ 2013 ┆ 33.26       ┆ 7.63        ┆ … ┆ null        ┆ null        ┆ null      ┆ null       │
# │ 15   ┆ 2013 ┆ 33.99       ┆ 7.59        ┆ … ┆ null        ┆ null        ┆ null      ┆ null       │
# │ 16   ┆ 2013 ┆ 30.57       ┆ 7.66        ┆ … ┆ null        ┆ null        ┆ null      ┆ null       │
# │ 17   ┆ 2013 ┆ 32.24       ┆ 7.63        ┆ … ┆ null        ┆ null        ┆ null      ┆ null       │
# │ 18   ┆ 2013 ┆ 34.63       ┆ 7.61        ┆ … ┆ null        ┆ null        ┆ null      ┆ null       │
# └──────┴──────┴─────────────┴─────────────┴───┴─────────────┴─────────────┴───────────┴────────────┘
# ['week', 'year', 'market_share', 'av_price_per_kg', 'non-promo_price_per_kg', 'promo_vol_share', 'total_weigh', 'share_of_ean_weigh', 'avg_price_vs_plb', 'non_promo_price_vs_plb', 'promo_vol_sh_index_vs_plb', 'total_cm_shelf', 'shelf_share', 'top_of_mind', 'spontaneous', 'aided', 'penetration', 'competitor', 'grp_radio', 'reach_radio', 'grp_tv', 'reach_tv', 'reach_cinema', 'grp_outdoor', 'grp_print', 'share_of_spend']

# %% [markdown]
# # <span style="color:brown;">Handle NA Values</span>

# %%
print(
    pl_mkt
    .null_count()
    .transpose(
        include_header=True,
        header_name="column",
        column_names=["null_count"]
    )
)
# Out:
# shape: (26, 2)
# ┌────────────────────────┬────────────┐
# │ column                 ┆ null_count │
# │ ---                    ┆ ---        │
# │ str                    ┆ u32        │
# ╞════════════════════════╪════════════╡
# │ week                   ┆ 0          │
# │ year                   ┆ 0          │
# │ market_share           ┆ 0          │
# │ av_price_per_kg        ┆ 0          │
# │ non-promo_price_per_kg ┆ 0          │
# │ …                      ┆ …          │
# │ reach_tv               ┆ 104        │
# │ reach_cinema           ┆ 138        │
# │ grp_outdoor            ┆ 155        │
# │ grp_print              ┆ 134        │
# │ share_of_spend         ┆ 40         │
# └────────────────────────┴────────────┘

# %%
# Drop columns where the NA values are more than 1/3 of the total observations

cols_to_drop = (
    pl_mkt
    .null_count()
    .transpose(
        include_header=True,
        header_name="column",
        column_names=["null_count"]
    )
    .filter(c('null_count') > (1/3 * pl_mkt.shape[0]))
    .get_column('column')
)

print(cols_to_drop)
# Out:
# shape: (7,)
# Series: 'column' [str]
# [
# 	"grp_radio"
# 	"reach_radio"
# 	"grp_tv"
# 	"reach_tv"
# 	"reach_cinema"
# 	"grp_outdoor"
# 	"grp_print"
# ]

# %%
pl_mkt_dropped = pl_mkt.drop(*cols_to_drop)

print(pl_mkt_dropped)
# Out:
# shape: (156, 19)
# ┌──────┬──────┬──────────────┬───────────────┬───┬───────┬─────────────┬────────────┬──────────────┐
# │ week ┆ year ┆ market_share ┆ av_price_per_ ┆ … ┆ aided ┆ penetration ┆ competitor ┆ share_of_spe │
# │ ---  ┆ ---  ┆ ---          ┆ kg            ┆   ┆ ---   ┆ ---         ┆ ---        ┆ nd           │
# │ i64  ┆ i64  ┆ f64          ┆ ---           ┆   ┆ f64   ┆ f64         ┆ f64        ┆ ---          │
# │      ┆      ┆              ┆ f64           ┆   ┆       ┆             ┆            ┆ f64          │
# ╞══════╪══════╪══════════════╪═══════════════╪═══╪═══════╪═════════════╪════════════╪══════════════╡
# │ 19   ┆ 2010 ┆ 38.4         ┆ 7.61          ┆ … ┆ null  ┆ null        ┆ null       ┆ null         │
# │ 20   ┆ 2010 ┆ 36.8         ┆ 7.6           ┆ … ┆ null  ┆ null        ┆ null       ┆ null         │
# │ 21   ┆ 2010 ┆ 35.21        ┆ 7.63          ┆ … ┆ null  ┆ null        ┆ null       ┆ null         │
# │ 22   ┆ 2010 ┆ 35.03        ┆ 7.22          ┆ … ┆ null  ┆ null        ┆ null       ┆ null         │
# │ 23   ┆ 2010 ┆ 32.37        ┆ 7.7           ┆ … ┆ null  ┆ null        ┆ null       ┆ null         │
# │ …    ┆ …    ┆ …            ┆ …             ┆ … ┆ …     ┆ …           ┆ …          ┆ …            │
# │ 14   ┆ 2013 ┆ 33.26        ┆ 7.63          ┆ … ┆ 99.5  ┆ 71.6        ┆ 4.6        ┆ null         │
# │ 15   ┆ 2013 ┆ 33.99        ┆ 7.59          ┆ … ┆ 99.5  ┆ 71.6        ┆ 4.7        ┆ null         │
# │ 16   ┆ 2013 ┆ 30.57        ┆ 7.66          ┆ … ┆ 99.5  ┆ 71.6        ┆ 4.6        ┆ null         │
# │ 17   ┆ 2013 ┆ 32.24        ┆ 7.63          ┆ … ┆ 99.5  ┆ 71.6        ┆ 4.7        ┆ null         │
# │ 18   ┆ 2013 ┆ 34.63        ┆ 7.61          ┆ … ┆ 99.5  ┆ 71.6        ┆ 5.0        ┆ null         │
# └──────┴──────┴──────────────┴───────────────┴───┴───────┴─────────────┴────────────┴──────────────┘

# %%
# Fill NA values with "mean" strategy

print(pl_mkt_dropped.fill_null(strategy = 'mean'))
# Out:
# shape: (156, 19)
# ┌──────┬──────┬─────────────┬─────────────┬───┬───────────┬─────────────┬────────────┬─────────────┐
# │ week ┆ year ┆ market_shar ┆ av_price_pe ┆ … ┆ aided     ┆ penetration ┆ competitor ┆ share_of_sp │
# │ ---  ┆ ---  ┆ e           ┆ r_kg        ┆   ┆ ---       ┆ ---         ┆ ---        ┆ end         │
# │ i64  ┆ i64  ┆ ---         ┆ ---         ┆   ┆ f64       ┆ f64         ┆ f64        ┆ ---         │
# │      ┆      ┆ f64         ┆ f64         ┆   ┆           ┆             ┆            ┆ f64         │
# ╞══════╪══════╪═════════════╪═════════════╪═══╪═══════════╪═════════════╪════════════╪═════════════╡
# │ 19   ┆ 2010 ┆ 38.4        ┆ 7.61        ┆ … ┆ 98.201626 ┆ 64.346341   ┆ 2.924324   ┆ 45.314027   │
# │ 20   ┆ 2010 ┆ 36.8        ┆ 7.6         ┆ … ┆ 98.201626 ┆ 64.346341   ┆ 2.924324   ┆ 45.314027   │
# │ 21   ┆ 2010 ┆ 35.21       ┆ 7.63        ┆ … ┆ 98.201626 ┆ 64.346341   ┆ 2.924324   ┆ 45.314027   │
# │ 22   ┆ 2010 ┆ 35.03       ┆ 7.22        ┆ … ┆ 98.201626 ┆ 64.346341   ┆ 2.924324   ┆ 45.314027   │
# │ 23   ┆ 2010 ┆ 32.37       ┆ 7.7         ┆ … ┆ 98.201626 ┆ 64.346341   ┆ 2.924324   ┆ 45.314027   │
# │ …    ┆ …    ┆ …           ┆ …           ┆ … ┆ …         ┆ …           ┆ …          ┆ …           │
# │ 14   ┆ 2013 ┆ 33.26       ┆ 7.63        ┆ … ┆ 99.5      ┆ 71.6        ┆ 4.6        ┆ 45.314027   │
# │ 15   ┆ 2013 ┆ 33.99       ┆ 7.59        ┆ … ┆ 99.5      ┆ 71.6        ┆ 4.7        ┆ 45.314027   │
# │ 16   ┆ 2013 ┆ 30.57       ┆ 7.66        ┆ … ┆ 99.5      ┆ 71.6        ┆ 4.6        ┆ 45.314027   │
# │ 17   ┆ 2013 ┆ 32.24       ┆ 7.63        ┆ … ┆ 99.5      ┆ 71.6        ┆ 4.7        ┆ 45.314027   │
# │ 18   ┆ 2013 ┆ 34.63       ┆ 7.61        ┆ … ┆ 99.5      ┆ 71.6        ┆ 5.0        ┆ 45.314027   │
# └──────┴──────┴─────────────┴─────────────┴───┴───────────┴─────────────┴────────────┴─────────────┘

# %%
# Fill NA values using machine learning KNNImputer from sklearn

from sklearn.impute import KNNImputer

pl_mkt_filled = pl.DataFrame(
    data = KNNImputer(n_neighbors = 10).fit_transform(pl_mkt_dropped.to_numpy()),
    schema = pl_mkt_dropped.columns
)

print(pl_mkt_filled)
# Out:
# shape: (156, 19)
# ┌──────┬────────┬──────────────┬──────────────┬───┬───────┬─────────────┬────────────┬─────────────┐
# │ week ┆ year   ┆ market_share ┆ av_price_per ┆ … ┆ aided ┆ penetration ┆ competitor ┆ share_of_sp │
# │ ---  ┆ ---    ┆ ---          ┆ _kg          ┆   ┆ ---   ┆ ---         ┆ ---        ┆ end         │
# │ f64  ┆ f64    ┆ f64          ┆ ---          ┆   ┆ f64   ┆ f64         ┆ f64        ┆ ---         │
# │      ┆        ┆              ┆ f64          ┆   ┆       ┆             ┆            ┆ f64         │
# ╞══════╪════════╪══════════════╪══════════════╪═══╪═══════╪═════════════╪════════════╪═════════════╡
# │ 19.0 ┆ 2010.0 ┆ 38.4         ┆ 7.61         ┆ … ┆ 98.3  ┆ 0.0         ┆ 0.63       ┆ 60.680307   │
# │ 20.0 ┆ 2010.0 ┆ 36.8         ┆ 7.6          ┆ … ┆ 98.3  ┆ 0.0         ┆ 0.63       ┆ 60.680307   │
# │ 21.0 ┆ 2010.0 ┆ 35.21        ┆ 7.63         ┆ … ┆ 98.3  ┆ 0.0         ┆ 0.63       ┆ 60.680307   │
# │ 22.0 ┆ 2010.0 ┆ 35.03        ┆ 7.22         ┆ … ┆ 98.3  ┆ 0.0         ┆ 0.63       ┆ 60.39927    │
# │ 23.0 ┆ 2010.0 ┆ 32.37        ┆ 7.7          ┆ … ┆ 98.3  ┆ 0.0         ┆ 0.63       ┆ 64.010652   │
# │ …    ┆ …      ┆ …            ┆ …            ┆ … ┆ …     ┆ …           ┆ …          ┆ …           │
# │ 14.0 ┆ 2013.0 ┆ 33.26        ┆ 7.63         ┆ … ┆ 99.5  ┆ 71.6        ┆ 4.6        ┆ 63.573102   │
# │ 15.0 ┆ 2013.0 ┆ 33.99        ┆ 7.59         ┆ … ┆ 99.5  ┆ 71.6        ┆ 4.7        ┆ 63.573102   │
# │ 16.0 ┆ 2013.0 ┆ 30.57        ┆ 7.66         ┆ … ┆ 99.5  ┆ 71.6        ┆ 4.6        ┆ 64.908432   │
# │ 17.0 ┆ 2013.0 ┆ 32.24        ┆ 7.63         ┆ … ┆ 99.5  ┆ 71.6        ┆ 4.7        ┆ 64.908432   │
# │ 18.0 ┆ 2013.0 ┆ 34.63        ┆ 7.61         ┆ … ┆ 99.5  ┆ 71.6        ┆ 5.0        ┆ 64.908432   │
# └──────┴────────┴──────────────┴──────────────┴───┴───────┴─────────────┴────────────┴─────────────┘

# %%
# Fill NA values using machine learning IterativeImputer from sklearn

from sklearn.experimental import enable_iterative_imputer  # This enables the experimental feature
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor

pl_mkt_filled = pl.DataFrame(
    data = IterativeImputer(max_iter=10, random_state=0, estimator=RandomForestRegressor()).fit_transform(pl_mkt_dropped.to_numpy()),
    schema = pl_mkt_dropped.columns
)

print(pl_mkt_filled)
# Out:
# shape: (156, 19)
# ┌──────┬────────┬──────────────┬─────────────┬───┬────────┬─────────────┬────────────┬─────────────┐
# │ week ┆ year   ┆ market_share ┆ av_price_pe ┆ … ┆ aided  ┆ penetration ┆ competitor ┆ share_of_sp │
# │ ---  ┆ ---    ┆ ---          ┆ r_kg        ┆   ┆ ---    ┆ ---         ┆ ---        ┆ end         │
# │ f64  ┆ f64    ┆ f64          ┆ ---         ┆   ┆ f64    ┆ f64         ┆ f64        ┆ ---         │
# │      ┆        ┆              ┆ f64         ┆   ┆        ┆             ┆            ┆ f64         │
# ╞══════╪════════╪══════════════╪═════════════╪═══╪════════╪═════════════╪════════════╪═════════════╡
# │ 19.0 ┆ 2010.0 ┆ 38.4         ┆ 7.61        ┆ … ┆ 98.055 ┆ 0.0         ┆ 0.701      ┆ 62.992447   │
# │ 20.0 ┆ 2010.0 ┆ 36.8         ┆ 7.6         ┆ … ┆ 98.121 ┆ 0.0         ┆ 0.722      ┆ 70.518443   │
# │ 21.0 ┆ 2010.0 ┆ 35.21        ┆ 7.63        ┆ … ┆ 98.099 ┆ 0.0         ┆ 0.727      ┆ 45.115148   │
# │ 22.0 ┆ 2010.0 ┆ 35.03        ┆ 7.22        ┆ … ┆ 98.081 ┆ 0.0         ┆ 0.611      ┆ 83.699315   │
# │ 23.0 ┆ 2010.0 ┆ 32.37        ┆ 7.7         ┆ … ┆ 98.115 ┆ 0.0         ┆ 0.684      ┆ 51.821826   │
# │ …    ┆ …      ┆ …            ┆ …           ┆ … ┆ …      ┆ …           ┆ …          ┆ …           │
# │ 14.0 ┆ 2013.0 ┆ 33.26        ┆ 7.63        ┆ … ┆ 99.5   ┆ 71.6        ┆ 4.6        ┆ 56.624822   │
# │ 15.0 ┆ 2013.0 ┆ 33.99        ┆ 7.59        ┆ … ┆ 99.5   ┆ 71.6        ┆ 4.7        ┆ 57.108684   │
# │ 16.0 ┆ 2013.0 ┆ 30.57        ┆ 7.66        ┆ … ┆ 99.5   ┆ 71.6        ┆ 4.6        ┆ 52.879011   │
# │ 17.0 ┆ 2013.0 ┆ 32.24        ┆ 7.63        ┆ … ┆ 99.5   ┆ 71.6        ┆ 4.7        ┆ 53.760388   │
# │ 18.0 ┆ 2013.0 ┆ 34.63        ┆ 7.61        ┆ … ┆ 99.5   ┆ 71.6        ┆ 5.0        ┆ 42.929337   │
# └──────┴────────┴──────────────┴─────────────┴───┴────────┴─────────────┴────────────┴─────────────┘

# %% [markdown]
# # <span style="color:brown;">Binning - Discretization</span>
